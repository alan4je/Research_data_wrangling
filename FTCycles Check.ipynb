# %%
import numpy as np
import pandas as pd
import xlsxwriter

# %%
db = pd.read_excel("../DataFiles/AnnualWeatherR.xlsx")

# %%
db.head()
# Out:
#    Year     MaxTMM     MinTMM  MaxTAnnualM  MixTAnnualM  AnnualPreci  \
# 0  1986  80.548387  36.903226    60.870289    46.679103         0.00
# 1  1987  76.612903  32.838710    61.769784    46.325115         0.00
# 2  1984  77.322581  30.677419    60.193314    46.055877         0.00
# 3  1985  83.000000  30.709677    59.158186    44.028123         0.00
# 4  1982  76.096774  37.000000    60.643363    46.190847       550.39
#
#    FTCycles Airport
# 0         4    KBFI
# 1         5    KBFI
# 2         9    KBFI
# 3        16    KBFI
# 4         8    KBFI

# %%
db[db.loc[:,'FTCycles'] > 100]
# Out:
#      Year     MaxTMM     MinTMM  MaxTAnnualM  MixTAnnualM  AnnualPreci  \
# 460  1986  70.161290  21.129032    45.720981    34.511636        92.62
# 462  1984  65.903226  18.258065    43.285824    32.656563        92.53
# 463  1985  72.645161  15.433333    43.649885    31.499814        75.39
# 464  1982  62.387097  21.387097    43.396729    33.090175      1004.22
# 465  1983  64.032258  14.548387    44.266852    34.212366        75.90
# 467  1981  69.516129  22.967742    45.705690    35.325467       823.59
# 468  1999  64.392857  25.363636    45.235291    34.467769        65.48
# 469  1998  70.800000  20.774194    46.723349    35.784281        78.51
# 470  1996  68.870968  20.129032    44.149446    33.377393       136.91
# 471  1993  63.100000  16.774194    44.424597    33.571563       149.54
# 472  1988  64.354839  20.838710    45.884291    35.173971        86.36
# 474  1991  65.354839  21.516129    46.105844    34.854192       183.96
# ...
