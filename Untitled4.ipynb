# %%
# Uploading the required packages
import pandas as pd, numpy as np

# %%
# Uploading the dataset
ds = pd.read_csv('cp255_A8.csv')

# %%
ds.head()
# Out:
#    Unnamed: 0   UID  tYear   AADT    ESAL  pTrucks  SingleTrucks  \
# 0           0     1   2004   8313   43508     2.86           198
# 1          25   153   2004  21022  275739    12.61          1987
# 2          39   262   2004  13536  171057    11.03          1052
# 3          81  1003   2004  12215   82362     5.88           471
# 4          82  1004   2004  14234   98203     6.29           625
#
#    DoubleTrucks  TrainTrucks  Unnamed: 0.1   ...    Prior Major Rehab Type  \
# 0            40            0        264764   ...                       NaN
# 1           595           69        263826   ...                       ACP
# 2           338          103           NaN   ...                       NaN
# 3           225           22           NaN   ...                       NaN
# 4           249           21           NaN   ...                       NaN
#
#    sfThick  Tthick  TSfThick  STcode        cumPPT  meanMinTemp  meanMaxTemp  \
# ...

# %%
data = ds.dropna(subset = ['cumPPT'])
print len(data.UID.unique())
print len(data)
# Out:
# 353
# 1986

# %%
data.head()
# Out:
#     Unnamed: 0   UID  tYear   AADT    ESAL  pTrucks  SingleTrucks  \
# 0            0     1   2004   8313   43508     2.86           198
# 1           25   153   2004  21022  275739    12.61          1987
# 7           97  1065   2004  15259  232669    10.51           696
# 9          116     1   2005   8337   43508     2.86           198
# 14         197  1003   2005  11591   96999     6.80           471
#
#     DoubleTrucks  TrainTrucks  Unnamed: 0.1   ...    Prior Major Rehab Type  \
# 0             40            0        264764   ...                       NaN
# 1            595           69        263826   ...                       ACP
# 7            790          117        263846   ...                       ACP
# 9             40            0        280428   ...                       NaN
# 14           284           34        279732   ...                       ACP
#
#     sfThick  Tthick  TSfThick  STcode        cumPPT  meanMinTemp  meanMaxTemp  \
# ...
